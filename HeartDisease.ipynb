# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/heart.csv')
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
data.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
data.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %% [markdown]
# ## **Distribution plot for numericals**

# %%
sns.distplot(data['Age'],color='red')
# Out:
# <ipython-input-14-c4c21acfa144>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'],color='red')
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(data['RestingBP'],color='blue')
# Out:
# <ipython-input-15-89251e188917>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['RestingBP'],color='blue')
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
sns.distplot(data['Cholesterol'],color='green')
# Out:
# <ipython-input-16-137e356a7eda>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Cholesterol'],color='green')
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
sns.distplot(data['MaxHR'],color='purple')
# Out:
# <ipython-input-19-c20ee79fd050>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['MaxHR'],color='purple')
# <Axes: xlabel='MaxHR', ylabel='Density'>

# %% [markdown]
# ## **Pie chart fot chategorical**

# %%
data.groupby('Sex').size().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %%
data.groupby('ChestPainType').size().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %%
data.groupby('RestingECG').size().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %%
data.groupby('ST_Slope').size().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %% [markdown]
# # **ViolinPlot**

# %%
sns.violinplot(y='Sex',x='Age',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Sex'>

# %%
sns.violinplot(x='HeartDisease',y='Age',data=data)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(x='HeartDisease',y='RestingBP',data=data)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='RestingBP'>

# %%
sns.violinplot(x='HeartDisease',y='Cholesterol',data=data)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
sns.violinplot(x='HeartDisease',y='MaxHR',data=data)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='MaxHR'>

# %% [markdown]
# # **Correlation - Heatmap**

# %%
data.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
data['Sex'] = data['Sex'].map({'M': 1, 'F': 0})

# %%
categorical_columns = ['ChestPainType', 'RestingECG', 'ST_Slope','ExerciseAngina']
for column in categorical_columns:
    data[column] = pd.factorize(data[column])[0]

data.corr()
# Out:
#                      Age       Sex  ChestPainType  RestingBP  Cholesterol  \
# Age             1.000000  0.055750       0.214164   0.254399    -0.095282
# Sex             0.055750  1.000000       0.179766   0.005133    -0.200092
# ChestPainType   0.214164  0.179766       1.000000   0.075332    -0.130997
# RestingBP       0.254399  0.005133       0.075332   1.000000     0.100893
# Cholesterol    -0.095282 -0.200092      -0.130997   0.100893     1.000000
# FastingBS       0.198039  0.120076       0.155111   0.070193    -0.260974
# RestingECG      0.213152 -0.018343       0.112067   0.097661     0.112095
# MaxHR          -0.382045 -0.189186      -0.273076  -0.112135     0.235792
# ExerciseAngina  0.215793  0.190664       0.324049   0.155101    -0.034166
# Oldpeak         0.258612  0.105734       0.300846   0.164803     0.050148
# ST_Slope        0.268264  0.150693       0.352364   0.075162    -0.111471
# HeartDisease    0.282039  0.305445       0.459017   0.107589    -0.232741
#
# ...

# %%
data.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40  NaN              0        140          289          0           0
# 1   49  NaN              1        160          180          0           0
# 2   37  NaN              0        130          283          0           1
# 3   48  NaN              2        138          214          0           0
# 4   54  NaN              1        150          195          0           0
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         0             0
# 1    156               0      1.0         1             1
# 2     98               0      0.0         0             0
# 3    108               1      1.5         1             1
# 4    122               0      0.0         0             0

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %% [markdown]
# # **Joint Plot**

# %%
sns.jointplot(x='Age',y='RestingBP',data=data)

# %%
sns.jointplot(x='Age',y='Cholesterol',data=data,kind="hex")

# %%
sns.jointplot(x='Age',y='MaxHR',data=data,kind='reg')

# %% [markdown]
# # **Pairplot**

# %%
sns.pairplot(data)
